# %% [markdown]
# ### image
# image -> image (image processing)
# image -> information (computer vision) ML/DL
# 이미지는 수학적으로 함수이다.
# 특정 값에 대한 밝기 / 색상을 나타내는 함수로 표현가능하다.

# %% [markdown]
# ## image = f(x,y) = array

# %%
import numpy as np

# %% [markdown]
# 다차원 배열 <연산> (=연산량이 많아서 느릴 수 밖에 없음)
# - cpu 최대한 활용 (vectorization)
# - 내부적으로 c
# - 효율적인 자료 구조
#
# 풍부한 기본 기능
#
# #### 현대적 관점에서 문제
# +Deep Learning , GPU
# pytorch -> numpy 기반으로 Tensor
# Tensorflow -> numpy 기반
#
# #### Vectorization
#
# #### image = file > array(numpy)

# %%
import PIL #Python imaging library

# %%
from PIL import Image

# %%
im = Image.open('IU.jpg')

# %%
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=196x257 at 0x1F606A83070>

# %%
import numpy as np

# %%
a = np.array([1,2,3])

# %%
a
# Out:
# array([1, 2, 3])

# %%
dir(im) #numpy와 호환
# Out:
# ['_Image__transformer',
#  '__array_interface__',
#  '__class__',
#  '__copy__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_category',
#  '_close_exclusive_fp_after_loading',
#  '_copy',
#  '_crop',
#  '_dump',
#  '_ensure_mutable',
#  '_exclusive_fp',
#  '_exif',
#  '_expand',
#  '_get_safe_box',
#  '_getexif',
#  '_getmp',
#  '_min_frame',
#  '_new',
#  '_open',
#  '_repr_png_',
#  '_seek_check',
#  '_size',
#  '_xmp',
#  'alpha_composite',
#  'app',
#  'applist',
#  'bits',
#  'close',
#  'convert',
#  'copy',
#  'crop',
# ...

# %%
import tensorflow as tf

# %%
b= tf.constant([1,2,3])

# %%
dir(b)
# Out:
# ['OVERLOADABLE_OPERATORS',
#  '_USE_EQUALITY',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_priority__',
#  '__bool__',
#  '__class__',
#  '__complex__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__index__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__long__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__nonzero__',
#  '__or__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdiv__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rmatmul__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__round__',
#  '__rpow__',
#  '__rsub__',
# ...

# %%
a= np.array(im)

# %%
a
# Out:
# array([[[222, 196, 173],
#         [222, 196, 173],
#         [222, 196, 173],
#         ...,
#         [207, 175, 154],
#         [207, 175, 154],
#         [207, 175, 154]],
#
#        [[222, 196, 173],
#         [222, 196, 173],
#         [222, 196, 173],
#         ...,
#         [207, 175, 154],
#         [207, 175, 154],
#         [207, 175, 154]],
#
#        [[222, 196, 173],
#         [222, 196, 173],
#         [222, 196, 173],
#         ...,
#         [207, 175, 154],
#         [207, 175, 154],
#         [207, 175, 154]],
#
#        ...,
#
#        [[245, 235, 225],
#         [246, 236, 226],
#         [247, 237, 227],
#         ...,
#         [137,  94,  39],
#         [195, 152, 101],
#         [212, 168, 121]],
#
#        [[243, 233, 223],
#         [244, 234, 224],
#         [245, 235, 225],
#         ...,
#         [134,  91,  38],
#         [204, 161, 110],
#         [202, 158, 111]],
#
#        [[247, 238, 221],
#         [248, 239, 222],
#         [248, 239, 224],
# ...

# %%
import matplotlib.pyplot as plt #array로 보는 방법

# %%
plt.imshow(a)

# %%
b=a[:140,70:220:,:] #slicing

# %%
plt.imshow(b)

# %%
#image에서 주로 사용하는 데이터는 uint8, float32

# %%
aa=a/255

# %%
aa.dtype
# Out:
# dtype('float64')

# %%
plt.imshow(aa) #상대적인 intensity

# %%
aa=aa.type('float32')
# Out:
# --------------------------------------------------------
# AttributeError         Traceback (most recent call last)
# <ipython-input-44-c887ddb5959a> in <module>
# ----> 1 aa=aa.type('float32')
#
# AttributeError: 'numpy.ndarray' object has no attribute 'type'
