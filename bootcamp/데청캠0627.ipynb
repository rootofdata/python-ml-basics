# %% [markdown]
#  # 자료형
# 표현식 = value로 가장 많은 타입은 정수이다. (숫자형 4가지로 구성)
#
# identity expression으로 표현 가능한 것.
# 오른쪽 하나의 결과값으로 표현할 수 있다. (함수 , 리스트 등등)

# %%
a=1

# %% [markdown]
# ## 정수형의 특징
# arbitary precision
# - 숫자의 범위가 없다. 무한대까지 정수의 형태를 만들 수 있다.

# %%
1==1 # 값을 비교
# Out:
# True

# %%
1 is 1 # memory를 비교
# Out:
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <ipython-input-221-9ef9bbd4944b>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   1 is 1 # memory를 비교
# True

# %%
a = 1000
b = 1000
a is b # False
# Out:
# False

# %%
0b03 #literal
# Out:
#   File "<ipython-input-223-07b3a56f72c7>", line 1
#     0b03 #literal
#        ^
# SyntaxError: invalid digit '3' in binary literal

# %% [markdown]
# ## literal
# literal : 데이터를 생성하기 위해서 쓰는 특수기호
# ex) 대괄호 등

# %%
a = 255
b = 255
a is b # True    #속도가 느리기 때문에 새로 생성하는 것이 아니라 캐시를 해버림.
# Out:
# True

# %%
import antigravity

# %% [markdown]
# ## 부동소수점
# 컴퓨터는 정확하게 계산할 수 없다.
# floating point
# float은 숫자의 범위가 있음

# %%
# 부동소수점
0.1+0.1+0.1
# Out:
# 0.30000000000000004

# %%
round(1.5)
# Out:
# 2

# %%
round(2.5)
# Out:
# 2

# %%
import sys

# %%
sys.float_info
# Out:
# sys.float_info(max=1.7976931348623157e+308, max_exp=1024, max_10_exp=308, min=2.2250738585072014e-308, min_exp=-1021, min_10_exp=-307, dig=15, mant_dig=53, epsilon=2.220446049250313e-16, radix=2, rounds=1)

# %%
1.7976931348623157e+308+1 == 1.7976931348623157e+308
# Out:
# True

# %%
1.7976931348623157e+309
# Out:
# inf

# %% [markdown]
# 숫자의 패턴을 알고 있어야 한다.
#
# 파이썬 coercion : 정수와 소수를 더하면 항상 소수가 된다는 보장이 없다. (암시적 형변환)
# complex : 복소수

# %%
import pandas as pd

# %% [markdown]
# ## bool type
# True는 1 False는 0

# %%
type(True)
# Out:
# bool

# %%
True
# Out:
# True

# %%
issubclass(bool,int)
# Out:
# True

# %% [markdown]
# # 정수형

# %%
#유니코드
'문근영'
# Out:
# '문근영'

# %%
#byte코드
b'문근영'
# Out:
#   File "<ipython-input-244-58ae68848700>", line 2
#     b'문근영'
#     ^
# SyntaxError: bytes can only contain ASCII literal characters.

# %%
b'moon'
# Out:
# b'moon'

# %%
memoryview
# Out:
# memoryview

# %%
100
# Out:
# 100

# %%
n
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-248-ab0680a89434> in <module>
# ----> 1 n
#
# NameError: name 'n' is not defined

# %% [markdown]
# ### container
#
# numpy -> homo 구조로 만들었다.
# 문자는 homo
#
# sequencial vs not sequencial이냐
# sequencial : set, dictionary
# not sequencial

# %%
import numpy as np

# %%
a= np.array([1,2,3,'4'])
a
# Out:
# array(['1', '2', '3', '4'], dtype='<U11')

# %%
import tensorflow as tf

# %%
a=tf.constant([1,2,3,4]) #homo로만 구성해야한다.

# %% [markdown]
# ## duck-typing
#
# __len__ , __getitem__        둘 다 있으면 덕타이핑 (인덱싱과 슬라이싱이 가능하다.)

# %%
a[0]
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=1>

# %%
a[:]
# Out:
# <tf.Tensor: shape=(4,), dtype=int32, numpy=array([1, 2, 3, 4])>

# %%
b={1,2}

# %%
dir(b)
# Out:
# ['__and__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__iand__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__isub__',
#  '__iter__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__rand__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__ror__',
#  '__rsub__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__xor__',
#  'add',
#  'clear',
#  'copy',
#  'difference',
#  'difference_update',
#  'discard',
#  'intersection',
#  'intersection_update',
#  'isdisjoint',
#  'issubset',
#  'issuperset',
#  'pop',
#  'remove',
#  'symmetric_difference',
#  'symmetric_difference_update',
#  'union',
#  'update']

# %% [markdown]
# mutable vs inmutable
# bytes array : mutable

# %%
range(10)[4]
# Out:
# 4

# %%
a=1,2

# %%
a  #tuple
# Out:
# (1, 2)

# %%
def x():
    return 1,2
x()
# Out:
# (1, 2)

# %%
for i in 1,2,3,4:
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
pd.DataFrame.from_record
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-262-d49b9863f077> in <module>
# ----> 1 pd.DataFrame.from_record
#
# AttributeError: type object 'DataFrame' has no attribute 'from_record'

# %%
import seaborn as sns
iris = sns.load_dataset('iris')

def t(*a):
    return a
t(1,2,3,4,5)
# Out:
# (1, 2, 3, 4, 5)

# %% [markdown]
# ### tuple은 형태가 일정한 inmutable이다.

# %%
a = 1
id(a)
# Out:
# 140723084142384

# %%
type(a)
# Out:
# int

# %% [markdown]
# 재할당 : 다시 할당한느 것
# 상수 : 할당할 수 없는 수
# 파이썬은 상수가 없다. (재할당 무조건 가능)
# keyword 뺴고 가능

# %%
a = 2

# %% [raw]
# import keyword

# %%
import keyword

# %%
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
a=[1,2,3]

# %%
id(a)
# Out:
# 2894816456064

# %%
a.append(4)
a
# Out:
# [1, 2, 3, 4]

# %%
id(a)
# Out:
# 2894816456064

# %%
import tensorflow as tf

# %%
x= tf.keras.applications.VGG16()
# Out:
# ...
# 172711936/553467096 [========>.....................] - ETA: 33s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-274-61b9b7b577df> in <module>
# ----> 1 x= tf.keras.applications.VGG16()
#
# ~\anaconda3\lib\site-packages\keras\applications\vgg16.py in VGG16(include_top, weights, input_tensor, input_shape, pooling, classes, classifier_activation)
#     210   if weights == 'imagenet':
#     211     if include_top:
# --> 212       weights_path = data_utils.get_file(
#     213           'vgg16_weights_tf_dim_ordering_tf_kernels.h5',
#     214           WEIGHTS_PATH,
#
# ~\anaconda3\lib\site-packages\keras\utils\data_utils.py in get_file(fname, origin, untar, md5_hash, file_hash, cache_subdir, hash_algorithm, extract, archive_format, cache_dir)
#     275     try:
#     276       try:
# --> 277         urlretrieve(origin, fpath, dl_progress)
# ...

# %%
x.weights
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-275-c5996befd9ec> in <module>
# ----> 1 x.weights
#
# AttributeError: 'function' object has no attribute 'weights'

# %%
a=[1,2,3]
def X(a):
    return a.append(4)
X(a)

# %% [markdown]
# ## mutable 3
# append
# pop
# index

# %%
b=a.append(4)

# %%
b is None
# Out:
# True

# %%
c=a.pop()
c
# Out:
# 4

# %%
a.index(3)
# Out:
# 2

# %%
import seaborn as sns
iris = sns.load_dataset('iris')
iris .drop(columns='sepal_length')
# Out:
#      sepal_width  petal_length  petal_width    species
# 0            3.5           1.4          0.2     setosa
# 1            3.0           1.4          0.2     setosa
# 2            3.2           1.3          0.2     setosa
# 3            3.1           1.5          0.2     setosa
# 4            3.6           1.4          0.2     setosa
# ..           ...           ...          ...        ...
# 145          3.0           5.2          2.3  virginica
# 146          2.5           5.0          1.9  virginica
# 147          3.0           5.2          2.0  virginica
# 148          3.4           5.4          2.3  virginica
# 149          3.0           5.1          1.8  virginica
#
# [150 rows x 4 columns]

# %%
frozenset
# Out:
# frozenset

# %%
def t(t):
    a=t*t
    return a
def s(t):
    return t*t

# %%
import dis

# %%
dis.dis(t)
# Out:
#   2           0 LOAD_FAST                0 (t)
#               2 LOAD_FAST                0 (t)
#               4 BINARY_MULTIPLY
#               6 STORE_FAST               1 (a)
#
#   3           8 LOAD_FAST                1 (a)
#              10 RETURN_VALUE

# %%
dis.dis(s)
# Out:
#   5           0 LOAD_FAST                0 (t)
#               2 LOAD_FAST                0 (t)
#               4 BINARY_MULTIPLY
#               6 RETURN_VALUE

# %% [markdown]
# #### set

# %%
a={3,2,1}

# %%
a
# Out:
# {1, 2, 3}

# %%
b={2,3,4}

# %%
b
# Out:
# {2, 3, 4}

# %%
a-b #차
# Out:
# {1}

# %%
a&b #교집합
# Out:
# {2, 3}

# %%
a|b #합집합
# Out:
# {1, 2, 3, 4}

# %%
c = tf.Variable([1,2,3])

# %%
c.assign([2,3,4])
# Out:
# <tf.Variable 'UnreadVariable' shape=(3,) dtype=int32, numpy=array([2, 3, 4])>

# %%
c
# Out:
# <tf.Variable 'Variable:0' shape=(3,) dtype=int32, numpy=array([2, 3, 4])>

# %%
d=frozenset([1,2,3])

# %%
{}
# Out:
# {}

# %%
set()
# Out:
# set()

# %%
y=[1,2,3]

# %%
x={'a':1}

# %%
x['b']=4

# %%
x
# Out:
# {'a': 1, 'b': 4}

# %%
x={1:1}

# %%
zz={(1,2,3) :1} #tuple 안 list는 안됨.

# %%
z=dict(a=1)

# %%
z
# Out:
# {'a': 1}

# %%
#dictunary 많이 사용하라
# 데이터를 뽑기 쉬움. list처럼 key를 숫자로 집어넣어서 사용할 수도 있다.
# expression은 하나의 결과값으로 축약할 수 있다.
#오른쪽에 올 수 있다.

# %%
a=1

# %%
from sklearn.datasets import load_boston

# %%
import tensorflow as tf

# %%
tf.keras.losses.binary_crossentropy
tf.keras.losses.BinaryCrossentropy
-camel binaryCrossentropy
-CapsWord (pascal) BinaryCrossentropy

python <= camel == pascal
# Out:
#   File "<ipython-input-312-55e1b553871f>", line 3
#     -camel binaryCrossentropy
#            ^
# SyntaxError: invalid syntax

# %%
a=1,2,3, # , : trailing comma

# %%
a, b = 1,2

# %%
a, b = b, a

# %%
a, b=0,1
def fib2(n):
    result=[]
    while a<n:
        result.append()
        a,b=b,a+b
    return resuilt

# %%
a,*b =1,2,3 #unpacking
#*b : 리스트
b
# Out:
# [2, 3]

# %%
a,*b,c=(1,2,3,4,5)

# %%
b
# Out:
# [2, 3, 4]

# %%
*a,=(1,2,3,4,5)

# %%
a #tuple을 list로 변환시킬 수 있음
# Out:
# [1, 2, 3, 4, 5]

# %%
a=b=[1,2,3]

# %%
c=b.copy()

# %%
c.append(4)

# %%
a
# Out:
# [1, 2, 3]

# %%
# 데이터 분석에서 copy / checkpoint 하는 것이 중요!
# 분석 진행에 있어 뒤로 못 돌린다.

# %%
b == b[:]
# Out:
# True

# %%
b is b[:] #메모리 번지가 다르다.
# Out:
# False

# %%
c=b
c.append(4)
a
# Out:
# [1, 2, 3, 4]

# %%
import seaborn as sns
iris[['petal_width','species']]
# Out:
#      petal_width    species
# 0            0.2     setosa
# 1            0.2     setosa
# 2            0.2     setosa
# 3            0.2     setosa
# 4            0.2     setosa
# ..           ...        ...
# 145          2.3  virginica
# 146          1.9  virginica
# 147          2.0  virginica
# 148          2.3  virginica
# 149          1.8  virginica
#
# [150 rows x 2 columns]

# %%
a=b=[[1,2],[3,4]]

# %%
c=a

# %%
c[0][0]=100

# %%
a
# Out:
# [[100, 2], [3, 4]]

# %%
b
# Out:
# [[100, 2], [3, 4]]

# %%
import copy

# %%
c=copy.deepcopy(a)

# %%
c[0][0]=100

# %%
c
# Out:
# [[100, 2], [3, 4]]

# %%
a
# Out:
# [[100, 2], [3, 4]]

# %%
import tensorflow as tf

# %%
len(tf.keras.datasets.mnist.load_data())
# Out:
# 2

# %%
a,b = tf.keras.datasets.mnist.load_data()

# %%
len(a)
# Out:
# 2

# %%
x,y=a ; u,w=b

# %%
(x,y),(u,w) = tf.keras.datasets.mnist.load_data()

# %%
if 3:
    print('a')
else:
    print('b')
# Out:
# a

# %%
if 0: #0. , "", [], None, list(), float(), tuple() 등등 : 없는 것은 다 거짓(False)라고 나타낸다.
    print('a')
else:
    print('b')
    #0 제외하고 다 a임.
# Out:
# b

# %%
False == None #False : 0이고, None는 0이 아니다.
# Out:
# False

# %%
import this
#Although that way may not be obvious at first unless you're Dutch

# %%
3 and 4 #short serkit (and : 앞만 반환)
# 앞 -> 참이면 뒷
# 앞 -> 거짓이면 앞
# Out:
# 4

# %%
[] and 4
# []는 비어있으니까 거짓 -> 앞을 출력
# Out:
# []

# %%
4 or 5
#앞 -> 참이면 앞
#앞 -> 거짓이면 뒤
# Out:
# 4

# %%
help('in')
# Out:
# Membership test operations
# **************************
#
# The operators "in" and "not in" test for membership.  "x in s"
# evaluates to "True" if *x* is a member of *s*, and "False" otherwise.
# "x not in s" returns the negation of "x in s".  All built-in sequences
# and set types support this as well as dictionary, for which "in" tests
# whether the dictionary has a given key. For container types such as
# list, tuple, set, frozenset, dict, or collections.deque, the
# expression "x in y" is equivalent to "any(x is e or x == e for e in
# y)".
#
# For the string and bytes types, "x in y" is "True" if and only if *x*
# is a substring of *y*.  An equivalent test is "y.find(x) != -1".
# Empty strings are always considered to be a substring of any other
# string, so """ in "abc"" will return "True".
#
# For user-defined classes which define the "__contains__()" method, "x
# in y" returns "True" if "y.__contains__(x)" returns a true value, and
# "False" otherwise.
#
# ...

# %%
1 in [1,2,3]
# Out:
# True

# %%
'1' in [1,2,3] #hetero type
# Out:
# False

# %%
'1' in '12345'
# Out:
# True

# %%
1 in '12345' #error homo에 1을 대입하면 error 가 뜬다.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-361-4c7a2aa5457f> in <module>
# ----> 1 1 in '12345' #error homo에 1을 대입하면 error 가 뜬다.
#
# TypeError: 'in <string>' requires string as left operand, not int

# %%
'1' not in '1234'
# Out:
# False

# %%
'1' in {1:'1'} #딕셔너리의 경우 key만 check
# Out:
# False

# %%
for i in {1:2,3:4,5:6}:
    print(i) #딕셔너리니까 key만 check
    #in 다음에 올 수 있는 것 : iterable
# Out:
# 1
# 3
# 5

# %% [markdown]
# __getitem__ , __len__ :sequence type
# __iter__ : iterable

# %%
a=[1,2,3]

# %%
'__iter__' in dir(a)
# Out:
# True

# %%
class A:
    pass

# %%
a = A()

# %%
for i in a:
    print(i) #iterable 하지 않는다.. -> iterable 알아야 한다.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-373-c324de4f8f18> in <module>
# ----> 1 for i in a:
#       2     print(i)
#
# TypeError: 'A' object is not iterable

# %%
class B:
    def __iter__(self):
        return iter('12')

# %%
b=B()

# %%
for i in b:
    print(i)
# Out:
# 1
# 2

# %%
import itertoolsa
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-381-94553a0549d9> in <module>
# ----> 1 import itertoolsa
#
# ModuleNotFoundError: No module named 'itertoolsa'

# %%
from collections import Iterable,Iterator
# Out:
# <ipython-input-382-0a4523aabcc8>:1: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3, and in 3.9 it will stop working
#   from collections import Iterable,Iterator

# %%
from sklearn.naive_bayes import ABCMeta

# %%
import dis

# %%
dis.dis(X)
# Out:
#   3           0 LOAD_FAST                0 (a)
#               2 LOAD_METHOD              0 (append)
#               4 LOAD_CONST               1 (4)
#               6 CALL_METHOD              1
#               8 RETURN_VALUE

# %%
for i in [1,2,3]:
    print(i)
else:
    print('end')
# Out:
# 1
# 2
# 3
# end

# %%
for i in range(10):
    if i==5:
        continue
    print(i)
else:
    print('end')
# Out:
# 0
# 1
# 2
# 3
# 4
# 6
# 7
# 8
# 9
# end

# %%
i =10
while (i>10):
    i -=1
    print(i)
else:
    print('end') #break가 걸리지 않고 0번 반복했다는 뜻.
    
    # else가 if에만 쓰이는 것이 아니라 for, while에도 쓰이는 것임.
    # 그렇지만 else 쓰이지 않는 이유 : 의사소통이 안된다 ㅋㅋ
# Out:
# end

# %%
## 용어 정리

# %%
# 파라미터 (parameter)
# 인자 (argument)

# %%
def x(a):
    return a

# %%
x(3) # 3: 인자
# Out:
# 3

# %%
def x(a):
    return a

# %%
#x  
#x()
#x(a) 
#여기서 함수 : x 이다.
#괄호를 붙일 수 있는 것이 따로 존재.

# %%
callable(x)
# Out:
# True

# %%
class A:
    pass

# %%
callable(A)
# Out:
# True

# %%
A()

# %%
def x(a,b=1):
    return a+b

# %%
x(1)
# Out:
# 2

# %%
x(1,2)
# Out:
# 3

# %%
# 키워드 방식
x(b=1,a=2)
# Out:
# 3

# %%
#positional 방식
x(2,3)
# Out:
# 5

# %%
len([1,2,3])
# Out:
# 3

# %%
len(obj=[1,2,3]) # / 기준으로 왼쪽은 positional 방식으로만 사용 가능하다.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-418-0144d2c059a3> in <module>
# ----> 1 len(obj=[1,2,3])
#
# TypeError: len() takes no keyword arguments

# %%
import matplotlib.pyplot as plt

# %%
plt.plot
# Out:
# <function matplotlib.pyplot.plot(*args, scalex=True, scaley=True, data=None, **kwargs)>

# %%
def t(a,*,b):
    return a+b

# %%
t(3,b=4)
# * 기준 오른쪽은 keyword 방식.
# Out:
# 7

# %%
def s(*a):
    return a
# *a : 가변 포지션 (안넣어도 실행)

# %%
s()
# Out:
# ()

# %%
s(1)
# Out:
# (1,)

# %%
sss = [1,2,3,4,5,]

# %%
s(sss)
# Out:
# ([1, 2, 3, 4, 5],)

# %%
s(*sss)
# Out:
# (1, 2, 3, 4, 5)

# %%
# argument의 *는 unpacking이라고 한다.
ss ={1:3,2:3}

# %%
s(ss)
# Out:
# ({1: 3, 2: 3},)

# %%
#parameter는 뒤에서부터 default를 채워가야한다.
def x(a=1,b):
    return a+b
# Out:
#   File "<ipython-input-435-9cdbac8e5d34>", line 2
#     def x(a=1,b):
#           ^
# SyntaxError: non-default argument follows default argument

# %%
def s(a,b=2,c=1):
    return a+b+c

# %%
s(a=1, 2,3) #keyword를 사용하면 계속 keyword 사용해야함.
# Out:
#   File "<ipython-input-439-194ad78c2246>", line 1
#     s(a=1, 2,3) #keyword를 사용하면 계속 keyword 사용해야함.
#            ^
# SyntaxError: positional argument follows keyword argument

# %%
s(a=1,b=2,c=3) #keyword 말하면 계속 keyword 사용해줘야함.
# Out:
# 6
