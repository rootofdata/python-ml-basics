# %%
a=input()
print(ord(a))

# %%
a=int(input())
b=int(input())

# %%
a=5
b=54321
list(b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-d97f7abc5551> in <module>
#       1 a=5
#       2 b=54321
# ----> 3 list(b)
#
# TypeError: 'int' object is not iterable
